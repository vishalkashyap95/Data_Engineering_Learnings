# %% [markdown]
# ### Assignment 2 - Week 2
# ### Create a pyspark script which will read data from particular table from Mysql/Postgres database
# ### Perform some operations/transformation on the data and save the result to local file storage

# %%
# Note - Launched pyspark with below command
# pyspark --driver-class-path .\postgresql-42.2.18.jar --jars .\postgresql-42.2.18.jar

from pyspark.sql import SparkSession
spark = SparkSession.builder.config('spark.driver.extraClassPath', "postgresql-42.2.18.jar").getOrCreate()
url = 'jdbc:postgresql://127.0.0.1/postgres'
properties = {'user': 'postgres', 'password': 'n0ob007'}
emp_df = spark.read.jdbc(url=url, table='Emp', properties=properties)

# %%
emp_df.show(100)
# Out:
# +-------+-----------------+-----------+
# |empname|   empdesignation|emplocation|
# +-------+-----------------+-----------+
# |   John|Software Engineer| California|
# |   Wade|    Data Engineer|    Toronto|
# | Vishal|    Data Engineer|     Mumbai|
# |   Adam|    Test Engineer|   New York|
# +-------+-----------------+-----------+

# %% [markdown]
# ### Converting Dataframe into RDD

# %%
emp_df.rdd.collect()
# Out:
# [Row(empname='John', empdesignation='Software Engineer', emplocation='California'),
#  Row(empname='Wade', empdesignation='Data Engineer', emplocation='Toronto'),
#  Row(empname='Vishal', empdesignation='Data Engineer', emplocation='Mumbai'),
#  Row(empname='Adam', empdesignation='Test Engineer', emplocation='New York')]

# %%
dd = sc.parallelize(emp_df.rdd.map(lambda row: row.asDict()).collect())

# %%
dd.collect()
# Out:
# [{'empname': 'John',
#   'empdesignation': 'Software Engineer',
#   'emplocation': 'California'},
#  {'empname': 'Wade',
#   'empdesignation': 'Data Engineer',
#   'emplocation': 'Toronto'},
#  {'empname': 'Vishal',
#   'empdesignation': 'Data Engineer',
#   'emplocation': 'Mumbai'},
#  {'empname': 'Adam',
#   'empdesignation': 'Test Engineer',
#   'emplocation': 'New York'}]

# %%
dd.collect()[0]['empdesignation']
# Out:
# 'Software Engineer'

# %% [markdown]
# ### Another way to convert Dataframe into RDD and then convert RDD into list of dict

# %%
emp_df.rdd.map(lambda row: row.asDict()).collect()
# Out:
# [{'empname': 'John',
#   'empdesignation': 'Software Engineer',
#   'emplocation': 'California'},
#  {'empname': 'Wade',
#   'empdesignation': 'Data Engineer',
#   'emplocation': 'Toronto'},
#  {'empname': 'Vishal',
#   'empdesignation': 'Data Engineer',
#   'emplocation': 'Mumbai'},
#  {'empname': 'Adam',
#   'empdesignation': 'Test Engineer',
#   'emplocation': 'New York'}]

# %% [markdown]
# ### Adding new column and transforming column

# %%
import pyspark.sql.functions as F
# new_emp_df = emp_df.withColumnRenamed('emplocation','emp_location')
# new_emp_df = new_emp_df.withColumnRenamed('empdesignation','emp_designation')
# new_emp_df = new_emp_df.withColumnRenamed('empname','emp_name')
new_emp_df = emp_df.select(
    F.col('emplocation').alias('emp_location'),F.col('empdesignation').alias('emp_designation'),F.col('empname').alias('emp_name')
)

# %%
new_emp_df.show()
# Out:
# +------------+-----------------+--------+
# |emp_location|  emp_designation|emp_name|
# +------------+-----------------+--------+
# |  California|Software Engineer|    John|
# |     Toronto|    Data Engineer|    Wade|
# |      Mumbai|    Data Engineer|  Vishal|
# |    New York|    Test Engineer|    Adam|
# +------------+-----------------+--------+

# %%
def extract_initials(col):
    splitted_data = str(col).strip().split()
    return ''.join([str(i[0]).upper() for i in splitted_data])

# %%
extract_initials("Data Engineer")
# Out:
# 'DE'

# %%
import pyspark.sql.functions as sqlFunc
import pyspark.sql.types as sqlTypes
usr_def_func = sqlFunc.UserDefinedFunction(extract_initials,sqlTypes.StringType())
transformed_emp_df = new_emp_df.withColumn('emp_desig_sf',usr_def_func('emp_designation'))
transformed_emp_df.show(100)
# Out:
# +------------+-----------------+--------+------------+
# |emp_location|  emp_designation|emp_name|emp_desig_sf|
# +------------+-----------------+--------+------------+
# |  California|Software Engineer|    John|          SE|
# |     Toronto|    Data Engineer|    Wade|          DE|
# |      Mumbai|    Data Engineer|  Vishal|          DE|
# |    New York|    Test Engineer|    Adam|          TE|
# +------------+-----------------+--------+------------+

# %%
transformed_emp_df.toPandas().to_csv("Transformed_emp_df.csv")

# %% [markdown]
# ### Assignment 3 - Week 3
# ### MoviLens dataset
# ### Dataset url:https://grouplens.org/datasets/movielens/
# ### Use PySpark for the followings
# ### Find the Most Popular Movie

# %%
import pandas as pd
links_df = pd.read_csv("./ml-latest-small/links.csv")
movies_df = pd.read_csv("./ml-latest-small/movies.csv")
ratings_df = pd.read_csv("./ml-latest-small/ratings.csv")
tags_df = pd.read_csv("./ml-latest-small/tags.csv")

# %%
links_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags_df.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %% [markdown]
# ### Top 25 most Rated movies

# %%
# Merging 2 dataframe (movies and ratings)
movies_ratings = pd.merge(movies_df,ratings_df)

# %%
movies_ratings.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %% [markdown]
# ### PANDAS : First way to find most rated movies by using Groupby

# %%
movies_ratings.groupby('title').size().to_frame().rename(columns={0:'Count'}).sort_values(by='Count',ascending=False).head(25)
# Out:
#                                                     Count
# title
# Forrest Gump (1994)                                   329
# Shawshank Redemption, The (1994)                      317
# Pulp Fiction (1994)                                   307
# Silence of the Lambs, The (1991)                      279
# Matrix, The (1999)                                    278
# Star Wars: Episode IV - A New Hope (1977)             251
# Jurassic Park (1993)                                  238
# Braveheart (1995)                                     237
# Terminator 2: Judgment Day (1991)                     224
# Schindler's List (1993)                               220
# Fight Club (1999)                                     218
# Toy Story (1995)                                      215
# Star Wars: Episode V - The Empire Strikes Back ...    211
# Usual Suspects, The (1995)                            204
# American Beauty (1999)                                204
# Seven (a.k.a. Se7en) (1995)                           203
# Independence Day (a.k.a. ID4) (1996)                  202
# Apollo 13 (1995)                                      201
# Raiders of the Lost Ark (Indiana Jones and the ...    200
# Lord of the Rings: The Fellowship of the Ring, ...    198
# Star Wars: Episode VI - Return of the Jedi (1983)     196
# Godfather, The (1972)                                 192
# Fugitive, The (1993)                                  190
# Batman (1989)                                         189
# Saving Private Ryan (1998)                            188

# %% [markdown]
# ### PANDAS : 2nd way to find most rated movies by values_count() method

# %%
movies_ratings['title'].value_counts().head(25)
# Out:
# Forrest Gump (1994)                                                               329
# Shawshank Redemption, The (1994)                                                  317
# Pulp Fiction (1994)                                                               307
# Silence of the Lambs, The (1991)                                                  279
# Matrix, The (1999)                                                                278
# Star Wars: Episode IV - A New Hope (1977)                                         251
# Jurassic Park (1993)                                                              238
# Braveheart (1995)                                                                 237
# Terminator 2: Judgment Day (1991)                                                 224
# Schindler's List (1993)                                                           220
# Fight Club (1999)                                                                 218
# Toy Story (1995)                                                                  215
# Star Wars: Episode V - The Empire Strikes Back (1980)                             211
# Usual Suspects, The (1995)                                                        204
# American Beauty (1999)                                                            204
# Seven (a.k.a. Se7en) (1995)                                                       203
# Independence Day (a.k.a. ID4) (1996)                                              202
# Apollo 13 (1995)                                                                  201
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    200
# Lord of the Rings: The Fellowship of the Ring, The (2001)                         198
# Star Wars: Episode VI - Return of the Jedi (1983)                                 196
# Godfather, The (1972)                                                             192
# Fugitive, The (1993)                                                              190
# Batman (1989)                                                                     189
# Saving Private Ryan (1998)                                                        188
# Name: title, dtype: int64

# %% [markdown]
# ### In Pyspark
# ### 1 : Read both the csv(movies.csv and ratings.csv)
# ### 2 : Merge both the csv using .join method
# ### 3 : converting dataframe into sql temp table and query via sql

# %%
spark_movies_df = spark.read.csv("./ml-latest-small/movies.csv",header=True)
spark_ratings_df = spark.read.csv("./ml-latest-small/ratings.csv",header=True)

# %%
spark_movies_df.show(5)
spark_ratings_df.show(5)
# Out:
# +-------+--------------------+--------------------+
# |movieId|               title|              genres|
# +-------+--------------------+--------------------+
# |      1|    Toy Story (1995)|Adventure|Animati...|
# |      2|      Jumanji (1995)|Adventure|Childre...|
# |      3|Grumpier Old Men ...|      Comedy|Romance|
# |      4|Waiting to Exhale...|Comedy|Drama|Romance|
# |      5|Father of the Bri...|              Comedy|
# +-------+--------------------+--------------------+
# only showing top 5 rows
#
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# |     1|      3|   4.0|964981247|
# |     1|      6|   4.0|964982224|
# |     1|     47|   5.0|964983815|
# |     1|     50|   5.0|964982931|
# +------+-------+------+---------+
# only showing top 5 rows

# %%
spark_movies_ratings_df = spark_movies_df.join(spark_ratings_df,on=['movieId'])

# %%
spark_movies_ratings_df.show(10)
# Out:
# +-------+--------------------+--------------------+------+------+---------+
# |movieId|               title|              genres|userId|rating|timestamp|
# +-------+--------------------+--------------------+------+------+---------+
# |      1|    Toy Story (1995)|Adventure|Animati...|     1|   4.0|964982703|
# |      3|Grumpier Old Men ...|      Comedy|Romance|     1|   4.0|964981247|
# |      6|         Heat (1995)|Action|Crime|Thri...|     1|   4.0|964982224|
# |     47|Seven (a.k.a. Se7...|    Mystery|Thriller|     1|   5.0|964983815|
# |     50|Usual Suspects, T...|Crime|Mystery|Thr...|     1|   5.0|964982931|
# |     70|From Dusk Till Da...|Action|Comedy|Hor...|     1|   3.0|964982400|
# |    101|Bottle Rocket (1996)|Adventure|Comedy|...|     1|   5.0|964980868|
# |    110|   Braveheart (1995)|    Action|Drama|War|     1|   4.0|964982176|
# |    151|      Rob Roy (1995)|Action|Drama|Roma...|     1|   5.0|964984041|
# |    157|Canadian Bacon (1...|          Comedy|War|     1|   5.0|964984100|
# +-------+--------------------+--------------------+------+------+---------+
# only showing top 10 rows

# %% [markdown]
# ### 1 way, via merging df and group by on dataframe

# %%
from pyspark.sql.functions import desc,col
# spark_movies_ratings_df.groupBy('title').count().orderBy('count',ascending=False).show(25)
spark_movies_ratings_df.groupBy('title').count().sort(col('count').desc()).show(25)
# Out:
# +--------------------+-----+
# |               title|count|
# +--------------------+-----+
# | Forrest Gump (1994)|  329|
# |Shawshank Redempt...|  317|
# | Pulp Fiction (1994)|  307|
# |Silence of the La...|  279|
# |  Matrix, The (1999)|  278|
# |Star Wars: Episod...|  251|
# |Jurassic Park (1993)|  238|
# |   Braveheart (1995)|  237|
# |Terminator 2: Jud...|  224|
# |Schindler's List ...|  220|
# |   Fight Club (1999)|  218|
# |    Toy Story (1995)|  215|
# |Star Wars: Episod...|  211|
# |Usual Suspects, T...|  204|
# |American Beauty (...|  204|
# |Seven (a.k.a. Se7...|  203|
# |Independence Day ...|  202|
# |    Apollo 13 (1995)|  201|
# |Raiders of the Lo...|  200|
# |Lord of the Rings...|  198|
# |Star Wars: Episod...|  196|
# |Godfather, The (1...|  192|
# |Fugitive, The (1993)|  190|
# |       Batman (1989)|  189|
# |Saving Private Ry...|  188|
# +--------------------+-----+
# only showing top 25 rows

# %% [markdown]
# ### 2nd way via SQL

# %%
spark_movies_ratings_df.registerTempTable("movies_ratings_table")

# %%
sqlContext.sql("select title,COUNT('title') from movies_ratings_table group by title order by 2 desc").show(25)
# Out:
# +--------------------+------------+
# |               title|count(title)|
# +--------------------+------------+
# | Forrest Gump (1994)|         329|
# |Shawshank Redempt...|         317|
# | Pulp Fiction (1994)|         307|
# |Silence of the La...|         279|
# |  Matrix, The (1999)|         278|
# |Star Wars: Episod...|         251|
# |Jurassic Park (1993)|         238|
# |   Braveheart (1995)|         237|
# |Terminator 2: Jud...|         224|
# |Schindler's List ...|         220|
# |   Fight Club (1999)|         218|
# |    Toy Story (1995)|         215|
# |Star Wars: Episod...|         211|
# |American Beauty (...|         204|
# |Usual Suspects, T...|         204|
# |Seven (a.k.a. Se7...|         203|
# |Independence Day ...|         202|
# |    Apollo 13 (1995)|         201|
# |Raiders of the Lo...|         200|
# |Lord of the Rings...|         198|
# |Star Wars: Episod...|         196|
# |Godfather, The (1...|         192|
# |Fugitive, The (1993)|         190|
# |       Batman (1989)|         189|
# |Lord of the Rings...|         188|
# +--------------------+------------+
# only showing top 25 rows

# %% [markdown]
# ### Assignment 4
# ### Spark Streaming
# ### Real-time Monitoring of the Most Popular Hashtags on Twitter

# %%
import tweepy
from tweepy.auth import OAuthHandler 
from tweepy import Stream
from tweepy.streaming import StreamListener
import json

# %%
# Tutorial followed
# https://towardsdatascience.com/sentiment-analysis-on-streaming-twitter-data-using-spark-structured-streaming-python-fc873684bfe3

consumer_key = "your key"
consumer_secret = "your secret"
access_token = "your token"
access_secret = "your secret"

# %%
class TweetStreamer():
    
    def stream_tweets(self, topic_to_search):
        tweetListner = TweetListner()
        auth = OAuthHandler(consumer_key,consumer_secret)
        auth.set_access_token(access_token,access_secret)

        stream = Stream(auth,tweetListner)
        stream.filter(track=topic_to_search)


class TweetListner(StreamListener):
    import pandas as pd    
    from collections import namedtuple
    fields = ("tags",'count')
    Tweets_count = namedtuple('Tweeet',fields)
    final_hashtags_list = []
    
    # Database connection section
    from pyspark.sql import SparkSession
    spark = SparkSession.builder.config('spark.driver.extraClassPath', "postgresql-42.2.18.jar").getOrCreate()
    url = 'jdbc:postgresql://127.0.0.1/postgres'
    properties = {'user': 'postgres', 'password': 'n0ob007'}
    df = spark.read.jdbc(url=url, table='popular_hashtags', properties=properties)
    df.show()
    
    # Variables for pyspark
    from pyspark.sql.types import StructField,StringType,StructType
    field = [
        StructField("hashtags", StringType(), True),
    ]
    schema = StructType(field)
    hashtags_spark_df = spark.createDataFrame(sc.emptyRDD(),schema)
    
    counter = 0
    
    def on_data(self,data):
        try:
#-------------Using Pandas---------------------
            # This piece of code, extract hashtags directly from the tweets
            hashTags = json.loads(data).get('entities').get('hashtags')
            if len(hashTags)>0:
                final_hashtags = hashTags[0].get('text')
                print(final_hashtags)
                            
                self.final_hashtags_list.append(final_hashtags)
                print(self.pd.Series(self.final_hashtags_list).value_counts().to_frame().rename(columns={0:'Count'}).head(10))
                print("-"*50)
#-------------Till here pandas---------------------

#-----------Using PySpark-----------------------
            # This piece of code, just receive tweets in str and converts it into json and extracts text using key(text)
            # Tweet text is then converted in to RDD and only #tags are extracted.
            # After extracting hashtags, I am forming a pyspark dataframe and inserting it into database(postgresql. Table[popular_hashtags])
            detailed_tweet = json.loads(data).get('text')
#             print(detailed_tweet)
#             print("Exxxx",'extended_tweet' in detailed_tweet)
#             if 'extended_tweet' in detailed_tweet:
#                 tweet_full_text = detailed_tweet['extended_tweet']['full_text'].encode('utf-8')
#             else:
#                 tweet_full_text = detailed_tweet['text'].encode('utf-8')
#             print(tweet_full_text)
            twt_rdd = sc.parallelize([detailed_tweet])
            print("RDD : ",twt_rdd.collect())
            extracted_hashtags = twt_rdd.flatMap(lambda lines: lines.split("\n")).flatMap(lambda each_lines:each_lines.split(" ")).filter(lambda x:x.lower().startswith("#"))
#             extracted_hashtags = twt_rdd.flatMap(lambda lines: self.split_lines_by(lines,"\n")).collect()
#             flatMap(lambda lines: self.split_lines_by(lines,"\n"))
#             .flatMap(lambda l:self.split_lines_by(l," ")).filter(lambda x:x.lower().startswith("#"))
            if extracted_hashtags.count()>0:
                print('Count of hashtags :',extracted_hashtags.count())
#                     [print(_ele) for _ele in extracted_hashtags.collect()]
                for _ele in extracted_hashtags.collect():
                    print("_ele --> ",_ele)
                    row = [[_ele]]
                    new_df = spark.createDataFrame(row)
                    # new_df.show()
                    self.hashtags_spark_df = self.hashtags_spark_df.union(new_df)
#                     self.hashtags_spark_df.show()
            self.hashtags_spark_df.show()
            print("-"*50)
        
            # At this line, if the pyspark dataframe count is divisible by 2 then insert in append mode in DB
            if self.hashtags_spark_df.count() > self.counter and self.hashtags_spark_df.count()%2==0:
                self.insert_into_db()
                self.counter = self.hashtags_spark_df.count() + 1
#-------------------------till here pyspark------------------------
            return True
        except Exception as e:
            print("Exception Caught while reading the data : ",str(e))
        return True
    
    def on_error(self, status):
        print("Error Found : ",status)
        return True

    def insert_into_db(self):
        print("Inside db method : ",self.hashtags_spark_df.count())
        self.hashtags_spark_df.write\
            .format("jdbc")\
            .mode("append")\
            .option("truncate","true")\
            .option("url",self.url)\
            .option("dbtable","popular_hashtags")\
            .option("user","postgres")\
            .option("password","n0ob007").save()

    def split_lines_by(lines,by):
        print("inside split by lines : ",lines.split(by))
        return lines.split(by)
# Out:
# +---------------------------+
# |                   hashtags|
# +---------------------------+
# |             #PMCBankCrisis|
# |                #SushantDay|
# |#NUEST_JR_아론_백호_민현_렌|
# |                  #뉴이스트|
# |                     #NUEST|
# |          #BoycottBollywood|
# |                #SushantDay|
# +---------------------------+

# %%
topic_to_search = ['Modi','SSR','football','cricket','Bollywood','Elon musk']
TweetStreamer().stream_tweets(topic_to_search)
# Out:
# SushantDay
#             Count
# SushantDay      1
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay      2
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay      3
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay      4
# --------------------------------------------------
# Gaius
#             Count
# SushantDay      4
# Gaius           1
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay      5
# Gaius           1
# --------------------------------------------------
# SWFC
#             Count
# SushantDay      5
# Gaius           1
# SWFC            1
# --------------------------------------------------
# CPFC
#             Count
# SushantDay      5
# SWFC            1
# Gaius           1
# CPFC            1
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay      6
# SWFC            1
# Gaius           1
# CPFC            1
# --------------------------------------------------
# CPFC
#             Count
# SushantDay      6
# CPFC            2
# SWFC            1
# Gaius           1
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay      7
# CPFC            2
# SWFC            1
# Gaius           1
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay      8
# CPFC            2
# SWFC            1
# Gaius           1
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay      9
# CPFC            2
# SWFC            1
# Gaius           1
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay     10
# CPFC            2
# SWFC            1
# Gaius           1
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay     11
# CPFC            2
# SWFC            1
# Gaius           1
# --------------------------------------------------
# Ronaldo
#             Count
# SushantDay     11
# CPFC            2
# Ronaldo         1
# SWFC            1
# Gaius           1
# --------------------------------------------------
# SushantDay
#             Count
# SushantDay     12
# CPFC            2
# Ronaldo         1
# SWFC            1
# Gaius           1
# --------------------------------------------------
# TelevisionStars
#                  Count
# SushantDay          12
# CPFC                 2
# Ronaldo              1
# TelevisionStars      1
# SWFC                 1
# Gaius                1
# --------------------------------------------------
# Gaius
#                  Count
# SushantDay          12
# Gaius                2
# CPFC                 2
# Ronaldo              1
# TelevisionStars      1
# SWFC                 1
# --------------------------------------------------
# NUEST_JR_아론_백호_민현_렌
#                      Count
# SushantDay              12
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              13
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              14
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# --------------------------------------------------
# 21DaysOfPrayers4SSR
#                      Count
# SushantDay              14
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              15
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              16
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# --------------------------------------------------
# mufc
#                      Count
# SushantDay              16
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# mufc                     1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              17
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# mufc                     1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              17
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# NFL                      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# mufc                     1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              18
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# NFL                      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# mufc                     1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              19
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# NFL                      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# mufc                     1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              20
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# NFL                      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# mufc                     1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              21
# Gaius                    2
# CPFC                     2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# NFL                      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# mufc                     1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              21
# Gaius                    2
# CPFC                     2
# NFL                      2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# mufc                     1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              22
# Gaius                    2
# CPFC                     2
# NFL                      2
# Ronaldo                  1
# TelevisionStars          1
# 21DaysOfPrayers4SSR      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# mufc                     1
# --------------------------------------------------
# HBLPSL
#                      Count
# SushantDay              22
# Gaius                    2
# CPFC                     2
# NFL                      2
# Ronaldo                  1
# TelevisionStars          1
# HBLPSL                   1
# 21DaysOfPrayers4SSR      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              23
# Gaius                    2
# CPFC                     2
# NFL                      2
# Ronaldo                  1
# TelevisionStars          1
# HBLPSL                   1
# 21DaysOfPrayers4SSR      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              24
# Gaius                    2
# CPFC                     2
# NFL                      2
# Ronaldo                  1
# TelevisionStars          1
# HBLPSL                   1
# 21DaysOfPrayers4SSR      1
# SWFC                     1
# NUEST_JR_아론_백호_민현_렌      1
# --------------------------------------------------
# DuPlessis
#                      Count
# SushantDay              24
# Gaius                    2
# CPFC                     2
# NFL                      2
# Ronaldo                  1
# TelevisionStars          1
# HBLPSL                   1
# 21DaysOfPrayers4SSR      1
# DuPlessis                1
# SWFC                     1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              25
# Gaius                    2
# CPFC                     2
# NFL                      2
# Ronaldo                  1
# TelevisionStars          1
# HBLPSL                   1
# 21DaysOfPrayers4SSR      1
# DuPlessis                1
# SWFC                     1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              26
# Gaius                    2
# CPFC                     2
# NFL                      2
# Ronaldo                  1
# TelevisionStars          1
# HBLPSL                   1
# 21DaysOfPrayers4SSR      1
# DuPlessis                1
# SWFC                     1
# --------------------------------------------------
# StartUpIndia
#                      Count
# SushantDay              26
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              27
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              28
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              29
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# sushanthsinghrajput
#                      Count
# SushantDay              29
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              30
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              31
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              32
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              33
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              34
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              35
# Gaius                    2
# CPFC                     2
# NFL                      2
# TelevisionStars          1
# HBLPSL                   1
# mufc                     1
# DuPlessis                1
# Ronaldo                  1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# Sushantday
#                  Count
# SushantDay          35
# Gaius                2
# CPFC                 2
# NFL                  2
# TelevisionStars      1
# HBLPSL               1
# mufc                 1
# DuPlessis            1
# Sushantday           1
# Ronaldo              1
# --------------------------------------------------
# NFL
#                  Count
# SushantDay          35
# NFL                  3
# Gaius                2
# CPFC                 2
# TelevisionStars      1
# HBLPSL               1
# mufc                 1
# DuPlessis            1
# Sushantday           1
# Ronaldo              1
# --------------------------------------------------
# SushantDay
#                  Count
# SushantDay          36
# NFL                  3
# Gaius                2
# CPFC                 2
# TelevisionStars      1
# HBLPSL               1
# mufc                 1
# DuPlessis            1
# Sushantday           1
# Ronaldo              1
# --------------------------------------------------
# SushantDay
#                  Count
# SushantDay          37
# NFL                  3
# Gaius                2
# CPFC                 2
# TelevisionStars      1
# HBLPSL               1
# mufc                 1
# DuPlessis            1
# Sushantday           1
# Ronaldo              1
# --------------------------------------------------
# SushantDay
#                  Count
# SushantDay          38
# NFL                  3
# Gaius                2
# CPFC                 2
# TelevisionStars      1
# HBLPSL               1
# mufc                 1
# DuPlessis            1
# Sushantday           1
# Ronaldo              1
# --------------------------------------------------
# AnushkaSharma
#                  Count
# SushantDay          38
# NFL                  3
# Gaius                2
# CPFC                 2
# TelevisionStars      1
# HBLPSL               1
# mufc                 1
# DuPlessis            1
# AnushkaSharma        1
# Sushantday           1
# --------------------------------------------------
# ssr
#                      Count
# SushantDay              38
# NFL                      3
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              38
# NFL                      4
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              39
# NFL                      4
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              40
# NFL                      4
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              41
# NFL                      4
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              42
# NFL                      4
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              42
# NFL                      5
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              43
# NFL                      5
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# fcblive
#                      Count
# SushantDay              43
# NFL                      5
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              44
# NFL                      5
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              44
# NFL                      6
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              44
# NFL                      7
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              44
# NFL                      8
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# StartUpIndia             1
# 21DaysOfPrayers4SSR      1
# --------------------------------------------------
# 戦艦少女R
#                      Count
# SushantDay              44
# NFL                      8
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# StartUpIndia             1
# --------------------------------------------------
# Kashmir
#                      Count
# SushantDay              44
# NFL                      8
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# StartUpIndia             1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              45
# NFL                      8
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# StartUpIndia             1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              45
# NFL                      9
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# StartUpIndia             1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              46
# NFL                      9
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# StartUpIndia             1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              47
# NFL                      9
# Gaius                    2
# CPFC                     2
# TelevisionStars          1
# Ronaldo                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# StartUpIndia             1
# --------------------------------------------------
# sus
#                      Count
# SushantDay              47
# NFL                      9
# Gaius                    2
# CPFC                     2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# StartUpIndia             1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              48
# NFL                      9
# Gaius                    2
# CPFC                     2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# StartUpIndia             1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              49
# NFL                      9
# Gaius                    2
# CPFC                     2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# StartUpIndia             1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              49
# NFL                     10
# Gaius                    2
# CPFC                     2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# StartUpIndia             1
# --------------------------------------------------
# 21DaysOfPrayers4SSR
#                      Count
# SushantDay              49
# NFL                     10
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              49
# NFL                     11
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              50
# NFL                     11
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# IPL2021
#                      Count
# SushantDay              50
# NFL                     11
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              51
# NFL                     11
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              52
# NFL                     11
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              53
# NFL                     11
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              54
# NFL                     11
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              55
# NFL                     11
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              55
# NFL                     12
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              56
# NFL                     12
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              57
# NFL                     12
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              58
# NFL                     12
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              59
# NFL                     12
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# Kashmir                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# StandWithFarmersChallenge
#                      Count
# SushantDay              59
# NFL                     12
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              60
# NFL                     12
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              61
# NFL                     12
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              62
# NFL                     12
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              62
# NFL                     13
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              63
# NFL                     13
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              64
# NFL                     13
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantSinghRajput
#                      Count
# SushantDay              64
# NFL                     13
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              65
# NFL                     13
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              66
# NFL                     13
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              67
# NFL                     13
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# SWFC                     1
# sushanthsinghrajput      1
# 戦艦少女R                    1
# --------------------------------------------------
# CoronaVaccine
#                      Count
# SushantDay              67
# NFL                     13
# Gaius                    2
# CPFC                     2
# 21DaysOfPrayers4SSR      2
# sus                      1
# fcblive                  1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# sushanthsinghrajput      1
# --------------------------------------------------
# デレステ名刺
#                      Count
# SushantDay              67
# NFL                     13
# Gaius                    2
# 21DaysOfPrayers4SSR      2
# CPFC                     2
# HBLPSL                   1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# Kashmir                  1
# StartUpIndia             1
# --------------------------------------------------
# football
#                      Count
# SushantDay              67
# NFL                     13
# Gaius                    2
# 21DaysOfPrayers4SSR      2
# CPFC                     2
# HBLPSL                   1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# Kashmir                  1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              68
# NFL                     13
# Gaius                    2
# 21DaysOfPrayers4SSR      2
# CPFC                     2
# HBLPSL                   1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# Kashmir                  1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              69
# NFL                     13
# Gaius                    2
# 21DaysOfPrayers4SSR      2
# CPFC                     2
# HBLPSL                   1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# Kashmir                  1
# --------------------------------------------------
# NFL
#                      Count
# SushantDay              69
# NFL                     14
# Gaius                    2
# 21DaysOfPrayers4SSR      2
# CPFC                     2
# HBLPSL                   1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# Kashmir                  1
# --------------------------------------------------
# Ronaldo
#                      Count
# SushantDay              69
# NFL                     14
# Gaius                    2
# Ronaldo                  2
# 21DaysOfPrayers4SSR      2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              70
# NFL                     14
# Gaius                    2
# Ronaldo                  2
# 21DaysOfPrayers4SSR      2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              71
# NFL                     14
# Gaius                    2
# Ronaldo                  2
# 21DaysOfPrayers4SSR      2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# 21DaysOfPrayers4SSR
#                      Count
# SushantDay              71
# NFL                     14
# 21DaysOfPrayers4SSR      3
# Gaius                    2
# Ronaldo                  2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              72
# NFL                     14
# 21DaysOfPrayers4SSR      3
# Gaius                    2
# Ronaldo                  2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              73
# NFL                     14
# 21DaysOfPrayers4SSR      3
# Gaius                    2
# Ronaldo                  2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              74
# NFL                     14
# 21DaysOfPrayers4SSR      3
# Gaius                    2
# Ronaldo                  2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              75
# NFL                     14
# 21DaysOfPrayers4SSR      3
# Gaius                    2
# Ronaldo                  2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              76
# NFL                     14
# 21DaysOfPrayers4SSR      3
# Gaius                    2
# Ronaldo                  2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay              77
# NFL                     14
# 21DaysOfPrayers4SSR      3
# Gaius                    2
# Ronaldo                  2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# SSR
#                      Count
# SushantDay              77
# NFL                     14
# 21DaysOfPrayers4SSR      3
# Gaius                    2
# Ronaldo                  2
# CPFC                     2
# DuPlessis                1
# NUEST_JR_아론_백호_민현_렌      1
# SWFC                     1
# football                 1
# --------------------------------------------------
# ssrbirthday
#                            Count
# SushantDay                    77
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    78
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    79
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    80
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    81
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    82
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    83
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    84
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    85
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    86
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    87
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    88
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    89
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    90
# NFL                           14
# 21DaysOfPrayers4SSR            3
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# 21DaysOfPrayers4SSR
#                            Count
# SushantDay                    90
# NFL                           14
# 21DaysOfPrayers4SSR            4
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    91
# NFL                           14
# 21DaysOfPrayers4SSR            4
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    92
# NFL                           14
# 21DaysOfPrayers4SSR            4
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    93
# NFL                           14
# 21DaysOfPrayers4SSR            4
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# NoRepealNoGharWapsi
#                            Count
# SushantDay                    93
# NFL                           14
# 21DaysOfPrayers4SSR            4
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    94
# NFL                           14
# 21DaysOfPrayers4SSR            4
# CPFC                           2
# Gaius                          2
# Ronaldo                        2
# ssrbirthday                    1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# farmersrprotest
#                            Count
# SushantDay                    94
# NFL                           14
# 21DaysOfPrayers4SSR            4
# Ronaldo                        2
# CPFC                           2
# Gaius                          2
# ssr                            1
# StandWithFarmersChallenge      1
# mufc                           1
# SSR                            1
# --------------------------------------------------
# SushantDay
#                            Count
# SushantDay                    95
# NFL                           14
# ...
# 21DaysOfPrayers4SSR      5
# Gaius                    3
# Ronaldo                  3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# SSR                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             123
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Gaius                    3
# Ronaldo                  3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# SSR                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             124
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Gaius                    3
# Ronaldo                  3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# SSR                      1
# --------------------------------------------------
# ramatheertham
#                      Count
# SushantDay             124
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Ronaldo                  3
# Gaius                    3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             125
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Ronaldo                  3
# Gaius                    3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             126
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Ronaldo                  3
# Gaius                    3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             127
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Ronaldo                  3
# Gaius                    3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             128
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Ronaldo                  3
# Gaius                    3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             129
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Ronaldo                  3
# Gaius                    3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             130
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Ronaldo                  3
# Gaius                    3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             131
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Ronaldo                  3
# Gaius                    3
# CPFC                     2
# mufc                     2
# 戦艦少女R                    2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# Histoire
#                      Count
# SushantDay             131
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Ronaldo                  3
# Gaius                    3
# mufc                     2
# 戦艦少女R                    2
# CPFC                     2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             132
# NFL                     14
# 21DaysOfPrayers4SSR      5
# Ronaldo                  3
# Gaius                    3
# mufc                     2
# 戦艦少女R                    2
# CPFC                     2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# 21DaysOfPrayers4SSR
#                      Count
# SushantDay             132
# NFL                     14
# 21DaysOfPrayers4SSR      6
# Ronaldo                  3
# Gaius                    3
# mufc                     2
# 戦艦少女R                    2
# CPFC                     2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             133
# NFL                     14
# 21DaysOfPrayers4SSR      6
# Ronaldo                  3
# Gaius                    3
# mufc                     2
# 戦艦少女R                    2
# CPFC                     2
# Bollywood                2
# ssr                      1
# --------------------------------------------------
# ssr
#                      Count
# SushantDay             133
# NFL                     14
# 21DaysOfPrayers4SSR      6
# Ronaldo                  3
# Gaius                    3
# mufc                     2
# 戦艦少女R                    2
# CPFC                     2
# ssr                      2
# Bollywood                2
# --------------------------------------------------
# CoronaVaccine
#                      Count
# SushantDay             133
# NFL                     14
# 21DaysOfPrayers4SSR      6
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CPFC                     2
# ssr                      2
# CoronaVaccine            2
# 戦艦少女R                    2
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             134
# NFL                     14
# 21DaysOfPrayers4SSR      6
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CPFC                     2
# ssr                      2
# CoronaVaccine            2
# 戦艦少女R                    2
# --------------------------------------------------
# Vijay
#                      Count
# SushantDay             134
# NFL                     14
# 21DaysOfPrayers4SSR      6
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# ssr                      2
# CoronaVaccine            2
# 戦艦少女R                    2
# mufc                     2
# --------------------------------------------------
# mufc
#                      Count
# SushantDay             134
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# ssr                      2
# CoronaVaccine            2
# 戦艦少女R                    2
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             135
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# ssr                      2
# CoronaVaccine            2
# 戦艦少女R                    2
# --------------------------------------------------
# ssr
#                      Count
# SushantDay             135
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# ssr                      3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CoronaVaccine            2
# 戦艦少女R                    2
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             136
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# ssr                      3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CoronaVaccine            2
# 戦艦少女R                    2
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             137
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# ssr                      3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CoronaVaccine            2
# 戦艦少女R                    2
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             138
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# ssr                      3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CoronaVaccine            2
# 戦艦少女R                    2
# --------------------------------------------------
# aaj
#                      Count
# SushantDay             138
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# ssr                      3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CPFC                     2
# CoronaVaccine            2
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             139
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# ssr                      3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CPFC                     2
# CoronaVaccine            2
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             140
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# ssr                      3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CPFC                     2
# CoronaVaccine            2
# --------------------------------------------------
# GulfKanawut
#                      Count
# SushantDay             140
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# ssr                      3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CoronaVaccine            2
# 戦艦少女R                    2
# --------------------------------------------------
# SushantDay
#                      Count
# SushantDay             141
# NFL                     14
# 21DaysOfPrayers4SSR      6
# mufc                     3
# ssr                      3
# Gaius                    3
# Ronaldo                  3
# Bollywood                2
# CoronaVaccine            2
# 戦艦少女R                    2
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-e624c4768e38> in <module>
#       1 topic_to_search = ['Modi','SSR','football','cricket','Bollywood','Elon musk']
# ----> 2 TweetStreamer().stream_tweets(topic_to_search)
#
# <ipython-input-52-9dec3b9c19f8> in stream_tweets(self, topic_to_search)
#       7
#       8         stream = Stream(auth,tweetListner)
# ----> 9         stream.filter(track=topic_to_search)
#      10
#      11
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     516             else:
#     517                 cache_content = False
# --> 518                 data = self._fp.read(amt) if not fp_closed else b""
#     519                 if (
#     520                     amt != 0 and not data
#
# c:\users\user\appdata\local\programs\python\python37\lib\http\client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# c:\users\user\appdata\local\programs\python\python37\lib\http\client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# c:\users\user\appdata\local\programs\python\python37\lib\http\client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# c:\users\user\appdata\local\programs\python\python37\lib\http\client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# c:\users\user\appdata\local\programs\python\python37\lib\http\client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# c:\users\user\appdata\local\programs\python\python37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# c:\users\user\appdata\local\programs\python\python37\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1047                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1048                   self.__class__)
# -> 1049             return self.read(nbytes, buffer)
#    1050         else:
#    1051             return super().recv_into(buffer, nbytes, flags)
#
# c:\users\user\appdata\local\programs\python\python37\lib\ssl.py in read(self, len, buffer)
#     906         try:
#     907             if buffer is not None:
# --> 908                 return self._sslobj.read(len, buffer)
#     909             else:
#     910                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Analysing popular hashtags by reading data from DB

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.config('spark.driver.extraClassPath', "postgresql-42.2.18.jar").getOrCreate()
url = 'jdbc:postgresql://127.0.0.1/postgres'
properties = {'user': 'postgres', 'password': 'n0ob007'}
popular_hashtags_df = spark.read.jdbc(url=url, table='popular_hashtags', properties=properties)
popular_hashtags_df.show()

# Grouping by hashtags
from pyspark.sql.functions import desc,col
popular_hashtags_df.groupBy('hashtags').count().sort(col('count').desc()).show(25)
# Out:
# +---------------------------+
# |                   hashtags|
# +---------------------------+
# |             #PMCBankCrisis|
# |                #SushantDay|
# |#NUEST_JR_아론_백호_민현_렌|
# |                  #뉴이스트|
# |                     #NUEST|
# |          #BoycottBollywood|
# |                #SushantDay|
# +---------------------------+
#
# +---------------------------+-----+
# |                   hashtags|count|
# +---------------------------+-----+
# |                #SushantDay|    2|
# |          #BoycottBollywood|    1|
# |                     #NUEST|    1|
# |                  #뉴이스트|    1|
# |#NUEST_JR_아론_백호_민현_렌|    1|
# |             #PMCBankCrisis|    1|
# +---------------------------+-----+
